# %% [markdown]
# ---
# #Imports
# ---

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.model_selection import GroupShuffleSplit
from PIL import Image
import json
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

cartella_grafici     = "/content/drive/MyDrive/Tesi/Grafici"
cartella_checkpoints = "/content/drive/MyDrive/Tesi/checkpoints"
os.makedirs(cartella_checkpoints, exist_ok=True)

IMG_SIZE = (224, 224)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# #Normalizzazione (non runnare)
# ---

# %%
#Runnare una volta sola
min_vel, max_vel   = np.inf, -np.inf
min_time, max_time = np.inf, -np.inf

for sim in sorted(os.listdir(cartella_grafici)):
    cartella_sim = os.path.join(cartella_grafici, sim)
    if not os.path.isdir(cartella_sim): continue
    if not sim.startswith("Simulazione"): continue

    for evento in sorted(os.listdir(cartella_sim)):
        cartella_ev = os.path.join(cartella_sim, evento)
        if not os.path.isdir(cartella_ev): continue

        path_vel  = os.path.join(cartella_ev, "slip_profile.png")
        path_time = os.path.join(cartella_ev, "slip_profile_time.png")

        if os.path.exists(path_vel):
            img = np.array(Image.open(path_vel).convert("L"), dtype=np.float32)
            min_vel = min(min_vel, img.min())
            max_vel = max(max_vel, img.max())

        if os.path.exists(path_time):
            img = np.array(Image.open(path_time).convert("L"), dtype=np.float32)
            min_time = min(min_time, img.min())
            max_time = max(max_time, img.max())

print(f"slip_profile      → min: {min_vel:.2f}, max: {max_vel:.2f}")
print(f"slip_profile_time → min: {min_time:.2f}, max: {max_time:.2f}")

np.save(os.path.join(cartella_grafici, "norm_vel.npy"),  np.array([min_vel, max_vel]))
np.save(os.path.join(cartella_grafici, "norm_time.npy"), np.array([min_time, max_time]))
print("Valori di normalizzazione salvati.")
# Out:
# slip_profile      → min: 0.00, max: 255.00
# slip_profile_time → min: 0.00, max: 255.00
# Valori di normalizzazione salvati.

# %% [markdown]
# ---
# #Dataset formazione (non runnare)
# ---

# %%
from scipy.stats import kurtosis as scipy_kurtosis, entropy as scipy_entropy

def calcola_feature_texture(img_vel, img_time):
    """Le 8 feature più importanti emerse dal Random Forest per sigma_n."""
    gy_v, gx_v = np.gradient(img_vel)
    grad_v = np.sqrt(gx_v**2 + gy_v**2)
    gy_t, gx_t = np.gradient(img_time)
    grad_t = np.sqrt(gx_t**2 + gy_t**2)

    flat_v = img_vel.flatten()
    hist_v, _ = np.histogram(flat_v, bins=32, range=(flat_v.min(), flat_v.max() + 1e-9))
    hist_v_norm = hist_v / (hist_v.sum() + 1e-9)

    return np.array([
        grad_v.std(),                      # vel_grad_std
        grad_v.mean(),                     # vel_grad_media
        flat_v.std(),                      # vel_std
        grad_t.mean(),                     # time_grad_media
        img_time.flatten().std(),          # time_std
        grad_t.std(),                      # time_grad_std
        scipy_entropy(hist_v_norm + 1e-9), # vel_entropia
        scipy_kurtosis(flat_v),            # vel_kurtosis
    ], dtype=np.float32)

# %%
norm_vel  = np.load(os.path.join(cartella_grafici, "norm_vel.npy"))
norm_time = np.load(os.path.join(cartella_grafici, "norm_time.npy"))

X_vel, X_time, X_fase, X_texture_raw, Y, Sim_ID = [], [], [], [], [], []
eventi_caricati, eventi_saltati = 0, 0

for sim in sorted(os.listdir(cartella_grafici)):
    cartella_sim = os.path.join(cartella_grafici, sim)
    if not os.path.isdir(cartella_sim): continue
    if not sim.startswith("Simulazione"): continue

    for evento in sorted(os.listdir(cartella_sim)):
        cartella_ev  = os.path.join(cartella_sim, evento)
        path_vel     = os.path.join(cartella_ev, "slip_profile.png")
        path_time    = os.path.join(cartella_ev, "slip_profile_time.png")
        path_meta    = os.path.join(cartella_ev, "dati.npz")

        if not all(os.path.exists(p) for p in [path_vel, path_time, path_meta]):
            eventi_saltati += 1
            continue

        img_vel  = np.array(Image.open(path_vel).convert("L").resize(IMG_SIZE), dtype=np.float32)
        img_vel  = (img_vel - norm_vel[0]) / (norm_vel[1] - norm_vel[0])

        img_time = np.array(Image.open(path_time).convert("L").resize(IMG_SIZE), dtype=np.float32)
        img_time = (img_time - norm_time[0]) / (norm_time[1] - norm_time[0])

        dati = np.load(path_meta, allow_pickle=True)
        meta = json.loads(str(dati['metadati']))

        fase = meta['tmin_s'] / meta['TMAX'] if meta['TMAX'] > 0 else 0.0
        texture = calcola_feature_texture(img_vel, img_time)

        X_vel.append(img_vel)
        X_time.append(img_time)
        X_fase.append(fase)
        X_texture_raw.append(texture)
        Y.append([meta['b'], meta['Dc_m'], meta['sigma_n_Pa']])
        Sim_ID.append(meta['simulazione_n'])
        eventi_caricati += 1

X_vel         = np.array(X_vel)[..., np.newaxis]
X_time        = np.array(X_time)[..., np.newaxis]
X_fase        = np.array(X_fase, dtype=np.float32).reshape(-1, 1)
X_texture_raw = np.array(X_texture_raw, dtype=np.float32)
Y             = np.array(Y, dtype=np.float32)
Sim_ID        = np.array(Sim_ID)

print(f"Eventi caricati: {eventi_caricati}")
print(f"Eventi saltati:  {eventi_saltati}")
print(f"X_vel shape:     {X_vel.shape}")
print(f"X_time shape:    {X_time.shape}")
print(f"X_fase shape:    {X_fase.shape}")
print(f"Range fase:      [{X_fase.min():.3f}, {X_fase.max():.3f}]")
print(f"X_texture_raw shape: {X_texture_raw.shape}")
print(f"Y shape:         {Y.shape}")
# Out:
# Eventi caricati: 4344
# Eventi saltati:  2
# X_vel shape:     (4344, 224, 224, 1)
# X_time shape:    (4344, 224, 224, 1)
# X_fase shape:    (4344, 1)
# Range fase:      [0.000, 0.999]
# X_texture_raw shape: (4344, 8)
# Y shape:         (4344, 3)

# %%
#Salva il dataset dopo averlo caricato — eseguire una volta sola
np.savez_compressed(
    os.path.join(cartella_grafici, "dataset_completo.npz"),
    X_vel=X_vel,
    X_time=X_time,
    X_fase=X_fase,
    X_texture_raw=X_texture_raw,
    Y=Y,
    Sim_ID=Sim_ID)
print("Dataset salvato.")
# Out:
# Dataset salvato.

# %% [markdown]
# ---
# #Caricamento del dataset
# ---

# %%
#Carica il dataset salvato
dati = np.load(os.path.join(cartella_grafici, "dataset_completo.npz"))
X_vel         = dati["X_vel"]
X_time        = dati["X_time"]
X_fase        = dati["X_fase"]
X_texture_raw = dati["X_texture_raw"]
Y             = dati["Y"]
Sim_ID        = dati["Sim_ID"]
print(f"Dataset caricato: {len(Y)} eventi")
# Out:
# Dataset caricato: 4344 eventi

# %%
Y_min = Y.min(axis=0)
Y_max = Y.max(axis=0)
Y_norm = (Y - Y_min) / (Y_max - Y_min)

np.save(os.path.join(cartella_grafici, "norm_Y_min.npy"), Y_min)
np.save(os.path.join(cartella_grafici, "norm_Y_max.npy"), Y_max)

gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(X_vel, Y_norm, groups=Sim_ID))

X_vel_train,  X_vel_test  = X_vel[train_idx],  X_vel[test_idx]
X_time_train, X_time_test = X_time[train_idx], X_time[test_idx]
X_fase_train, X_fase_test = X_fase[train_idx], X_fase[test_idx]
Y_train,      Y_test      = Y_norm[train_idx], Y_norm[test_idx]

#Standardizzazione delle feature di texture: media/std calcolate sul training
tex_mean = X_texture_raw[train_idx].mean(axis=0)
tex_std  = X_texture_raw[train_idx].std(axis=0) + 1e-9
np.save(os.path.join(cartella_grafici, "tex_mean.npy"), tex_mean)
np.save(os.path.join(cartella_grafici, "tex_std.npy"),  tex_std)

X_texture_train = (X_texture_raw[train_idx] - tex_mean) / tex_std
X_texture_test  = (X_texture_raw[test_idx]  - tex_mean) / tex_std

print(f"Training: {len(Y_train)} eventi ({len(np.unique(Sim_ID[train_idx]))} simulazioni)")
print(f"Test:     {len(Y_test)} eventi ({len(np.unique(Sim_ID[test_idx]))} simulazioni)")

sigma_discreto = np.where(Y[train_idx, 2] > 90e6, "100", "80")
pesi_sigma_train = compute_sample_weight(class_weight='balanced', y=sigma_discreto)
pesi_sigma_train = np.clip(pesi_sigma_train, 0.2, 5.0)
# Out:
# Training: 3593 eventi (184 simulazioni)
# Test:     751 eventi (47 simulazioni)

# %% [markdown]
# ---
# #Architettura CNN con due rami paralleli
# ---

# %%
def build_model(input_shape=(224, 224, 1), n_texture=8):

    def cnn_branch(input_tensor, name):
        x = layers.Conv2D(32, (3,3), activation="relu", padding="same", name=f"{name}_conv1")(input_tensor)
        x = layers.BatchNormalization(name=f"{name}_bn1")(x)
        x = layers.MaxPooling2D(name=f"{name}_pool1")(x)

        x = layers.Conv2D(64, (3,3), activation="relu", padding="same", name=f"{name}_conv2")(x)
        x = layers.BatchNormalization(name=f"{name}_bn2")(x)
        x = layers.MaxPooling2D(name=f"{name}_pool2")(x)

        x = layers.Conv2D(128, (3,3), activation="relu", padding="same", name=f"{name}_conv3")(x)
        x = layers.BatchNormalization(name=f"{name}_bn3")(x)
        x = layers.MaxPooling2D(name=f"{name}_pool3")(x)

        x = layers.GlobalAveragePooling2D(name=f"{name}_gap")(x)
        return x

    input_vel     = keras.Input(shape=input_shape, name="slip_profile_vel")
    input_time    = keras.Input(shape=input_shape, name="slip_profile_time")
    input_fase    = keras.Input(shape=(1,), name="fase_ciclo")
    input_texture = keras.Input(shape=(n_texture,), name="texture_features")

    branch_vel     = cnn_branch(input_vel,  "vel")
    branch_time    = cnn_branch(input_time, "time")
    branch_fase    = layers.Dense(8, activation="relu", name="fase_dense")(input_fase)
    branch_texture = layers.Dense(16, activation="relu", name="texture_dense1")(input_texture)
    branch_texture = layers.Dense(16, activation="relu", name="texture_dense2")(branch_texture)

    fusion = layers.Concatenate(name="fusion")([branch_vel, branch_time, branch_fase, branch_texture])
    fusion = layers.Dense(256, activation="relu", name="dense1")(fusion)
    fusion = layers.Dropout(0.2, name="dropout1")(fusion)
    fusion = layers.Dense(64, activation="relu", name="dense2")(fusion)
    fusion = layers.Dropout(0.1, name="dropout2")(fusion)

    ramo_b = layers.Dense(64, activation="relu", name="b_dense1")(fusion)
    ramo_b = layers.Dropout(0.05, name="b_dropout")(ramo_b)
    ramo_b = layers.Dense(32, activation="relu", name="b_dense2")(ramo_b)
    out_b  = layers.Dense(1, activation="sigmoid", name="output_b")(ramo_b)

    out_Dc    = layers.Dense(1, activation="sigmoid", name="output_Dc")(fusion)
    out_sigma = layers.Dense(1, activation="sigmoid", name="output_sigma")(fusion)

    model = keras.Model(
        inputs=[input_vel, input_time, input_fase, input_texture],
        outputs=[out_b, out_Dc, out_sigma])
    return model

model = build_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ slip_profile_vel    │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ slip_profile_time   │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_conv1 (Conv2D)  │ (None, 224, 224,  │        320 │ slip_profile_vel… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_conv1 (Conv2D) │ (None, 224, 224,  │        320 │ slip_profile_tim… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_bn1             │ (None, 224, 224,  │        128 │ vel_conv1[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_bn1            │ (None, 224, 224,  │        128 │ time_conv1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_pool1           │ (None, 112, 112,  │          0 │ vel_bn1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_pool1          │ (None, 112, 112,  │          0 │ time_bn1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_conv2 (Conv2D)  │ (None, 112, 112,  │     18,496 │ vel_pool1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_conv2 (Conv2D) │ (None, 112, 112,  │     18,496 │ time_pool1[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_bn2             │ (None, 112, 112,  │        256 │ vel_conv2[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_bn2            │ (None, 112, 112,  │        256 │ time_conv2[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_pool2           │ (None, 56, 56,    │          0 │ vel_bn2[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_pool2          │ (None, 56, 56,    │          0 │ time_bn2[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_conv3 (Conv2D)  │ (None, 56, 56,    │     73,856 │ vel_pool2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_conv3 (Conv2D) │ (None, 56, 56,    │     73,856 │ time_pool2[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_bn3             │ (None, 56, 56,    │        512 │ vel_conv3[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_bn3            │ (None, 56, 56,    │        512 │ time_conv3[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ texture_features    │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_pool3           │ (None, 28, 28,    │          0 │ vel_bn3[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_pool3          │ (None, 28, 28,    │          0 │ time_bn3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fase_ciclo          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ texture_dense1      │ (None, 16)        │        144 │ texture_features… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vel_gap             │ (None, 128)       │          0 │ vel_pool3[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_gap            │ (None, 128)       │          0 │ time_pool3[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fase_dense (Dense)  │ (None, 8)         │         16 │ fase_ciclo[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ texture_dense2      │ (None, 16)        │        272 │ texture_dense1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 280)       │          0 │ vel_gap[0][0],    │
# │ (Concatenate)       │                   │            │ time_gap[0][0],   │
# │                     │                   │            │ fase_dense[0][0], │
# │                     │                   │            │ texture_dense2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 256)       │     71,936 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout1 (Dropout)  │ (None, 256)       │          0 │ dense1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense2 (Dense)      │ (None, 64)        │     16,448 │ dropout1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout2 (Dropout)  │ (None, 64)        │          0 │ dense2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ b_dense1 (Dense)    │ (None, 64)        │      4,160 │ dropout2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ b_dropout (Dropout) │ (None, 64)        │          0 │ b_dense1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ b_dense2 (Dense)    │ (None, 32)        │      2,080 │ b_dropout[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_b (Dense)    │ (None, 1)         │         33 │ b_dense2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_Dc (Dense)   │ (None, 1)         │         65 │ dropout2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_sigma        │ (None, 1)         │         65 │ dropout2[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 282,355 (1.08 MB)
#  Trainable params: 281,459 (1.07 MB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ---
# #Training con checkpoint
# ---

# %%
#Percorso checkpoint
ckpt_best      = os.path.join(cartella_checkpoints, "model_best.keras")
ckpt_periodico = os.path.join(cartella_checkpoints, "model_epoch_{epoch:03d}.keras")

#Carica checkpoint se esiste
resume = True
if resume and os.path.exists(ckpt_best):
    model = keras.models.load_model(ckpt_best)
    print(f"Checkpoint caricato: {ckpt_best}")
else:
    model = build_model()
    print("Nessun checkpoint trovato, si parte da zero.")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss=["huber", "mse", "mse"],   #Huber per b, invariato per Dc e sigma_n
    loss_weights=[1.0, 1.0, 1.0],
    metrics=[["mae"], ["mae"], ["mae"]]
)

callbacks = [
    keras.callbacks.ModelCheckpoint(filepath=ckpt_best, monitor="val_loss", save_best_only=True, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath=ckpt_periodico, save_freq=10, verbose=0),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True, verbose=1)
]

history = model.fit(
    x={
        "slip_profile_vel":  X_vel_train,
        "slip_profile_time": X_time_train,
        "fase_ciclo":        X_fase_train,
        "texture_features":  X_texture_train,
    },
    y=[Y_train[:, 0], Y_train[:, 1], Y_train[:, 2]],
    sample_weight=[
        np.ones(len(Y_train)),
        np.ones(len(Y_train)),
        pesi_sigma_train,
    ],
    validation_data=(
        {
            "slip_profile_vel":  X_vel_test,
            "slip_profile_time": X_time_test,
            "fase_ciclo":        X_fase_test,
            "texture_features":  X_texture_test,
        },
        [Y_test[:, 0], Y_test[:, 1], Y_test[:, 2]]
    ),
    epochs=500,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Checkpoint caricato: /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# Epoch 1/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 0.1173 - output_Dc_loss: 0.0187 - output_Dc_mae: 0.1075 - output_b_loss: 0.0477 - output_b_mae: 0.2659 - output_sigma_loss: 0.0509 - output_sigma_mae: 0.2052
# Epoch 1: val_loss improved from None to 0.19218, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 40s 231ms/step - loss: 0.1170 - output_Dc_loss: 0.0172 - output_Dc_mae: 0.1040 - output_b_loss: 0.0488 - output_b_mae: 0.2699 - output_sigma_loss: 0.0508 - output_sigma_mae: 0.2054 - val_loss: 0.1922 - val_output_Dc_loss: 0.0968 - val_output_Dc_mae: 0.2567 - val_output_b_loss: 0.0346 - val_output_b_mae: 0.2171 - val_output_sigma_loss: 0.0597 - val_output_sigma_mae: 0.2052 - learning_rate: 1.0000e-04
# Epoch 2/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1157 - output_Dc_loss: 0.0152 - output_Dc_mae: 0.0972 - output_b_loss: 0.0496 - output_b_mae: 0.2735 - output_sigma_loss: 0.0510 - output_sigma_mae: 0.2034
# Epoch 2: val_loss improved from 0.19218 to 0.17190, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1144 - output_Dc_loss: 0.0151 - output_Dc_mae: 0.0973 - output_b_loss: 0.0484 - output_b_mae: 0.2687 - output_sigma_loss: 0.0508 - output_sigma_mae: 0.2039 - val_loss: 0.1719 - val_output_Dc_loss: 0.0840 - val_output_Dc_mae: 0.2254 - val_output_b_loss: 0.0329 - val_output_b_mae: 0.2131 - val_output_sigma_loss: 0.0584 - val_output_sigma_mae: 0.2230 - learning_rate: 1.0000e-04
# Epoch 3/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.1159 - output_Dc_loss: 0.0165 - output_Dc_mae: 0.1004 - output_b_loss: 0.0491 - output_b_mae: 0.2712 - output_sigma_loss: 0.0502 - output_sigma_mae: 0.2015
# Epoch 3: val_loss did not improve from 0.17190
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - loss: 0.1150 - output_Dc_loss: 0.0161 - output_Dc_mae: 0.0999 - output_b_loss: 0.0486 - output_b_mae: 0.2686 - output_sigma_loss: 0.0505 - output_sigma_mae: 0.2022 - val_loss: 0.2156 - val_output_Dc_loss: 0.1122 - val_output_Dc_mae: 0.2738 - val_output_b_loss: 0.0357 - val_output_b_mae: 0.2208 - val_output_sigma_loss: 0.0664 - val_output_sigma_mae: 0.2059 - learning_rate: 1.0000e-04
# Epoch 4/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1145 - output_Dc_loss: 0.0149 - output_Dc_mae: 0.0962 - output_b_loss: 0.0497 - output_b_mae: 0.2752 - output_sigma_loss: 0.0499 - output_sigma_mae: 0.2027
# Epoch 4: val_loss did not improve from 0.17190
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.1124 - output_Dc_loss: 0.0145 - output_Dc_mae: 0.0945 - output_b_loss: 0.0479 - output_b_mae: 0.2673 - output_sigma_loss: 0.0503 - output_sigma_mae: 0.2028 - val_loss: 0.3170 - val_output_Dc_loss: 0.2004 - val_output_Dc_mae: 0.3570 - val_output_b_loss: 0.0364 - val_output_b_mae: 0.2232 - val_output_sigma_loss: 0.0852 - val_output_sigma_mae: 0.2398 - learning_rate: 1.0000e-04
# Epoch 5/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1111 - output_Dc_loss: 0.0140 - output_Dc_mae: 0.0939 - output_b_loss: 0.0472 - output_b_mae: 0.2626 - output_sigma_loss: 0.0499 - output_sigma_mae: 0.2023
# Epoch 5: val_loss did not improve from 0.17190
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 143ms/step - loss: 0.1131 - output_Dc_loss: 0.0144 - output_Dc_mae: 0.0943 - output_b_loss: 0.0480 - output_b_mae: 0.2659 - output_sigma_loss: 0.0508 - output_sigma_mae: 0.2045 - val_loss: 0.2002 - val_output_Dc_loss: 0.1137 - val_output_Dc_mae: 0.2796 - val_output_b_loss: 0.0328 - val_output_b_mae: 0.2126 - val_output_sigma_loss: 0.0516 - val_output_sigma_mae: 0.2086 - learning_rate: 1.0000e-04
# Epoch 6/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1147 - output_Dc_loss: 0.0157 - output_Dc_mae: 0.0988 - output_b_loss: 0.0484 - output_b_mae: 0.2697 - output_sigma_loss: 0.0505 - output_sigma_mae: 0.2005
# Epoch 6: val_loss improved from 0.17190 to 0.15525, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.1128 - output_Dc_loss: 0.0149 - output_Dc_mae: 0.0967 - output_b_loss: 0.0476 - output_b_mae: 0.2661 - output_sigma_loss: 0.0502 - output_sigma_mae: 0.2009 - val_loss: 0.1553 - val_output_Dc_loss: 0.0658 - val_output_Dc_mae: 0.1982 - val_output_b_loss: 0.0330 - val_output_b_mae: 0.2140 - val_output_sigma_loss: 0.0592 - val_output_sigma_mae: 0.2200 - learning_rate: 1.0000e-04
# Epoch 7/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.1093 - output_Dc_loss: 0.0119 - output_Dc_mae: 0.0867 - output_b_loss: 0.0474 - output_b_mae: 0.2656 - output_sigma_loss: 0.0500 - output_sigma_mae: 0.2026
# Epoch 7: val_loss did not improve from 0.15525
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.1093 - output_Dc_loss: 0.0126 - output_Dc_mae: 0.0887 - output_b_loss: 0.0471 - output_b_mae: 0.2647 - output_sigma_loss: 0.0494 - output_sigma_mae: 0.2005 - val_loss: 0.2636 - val_output_Dc_loss: 0.1464 - val_output_Dc_mae: 0.3010 - val_output_b_loss: 0.0404 - val_output_b_mae: 0.2342 - val_output_sigma_loss: 0.0809 - val_output_sigma_mae: 0.2367 - learning_rate: 1.0000e-04
# Epoch 8/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1104 - output_Dc_loss: 0.0130 - output_Dc_mae: 0.0905 - output_b_loss: 0.0480 - output_b_mae: 0.2678 - output_sigma_loss: 0.0494 - output_sigma_mae: 0.1990
# Epoch 8: val_loss did not improve from 0.15525
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1095 - output_Dc_loss: 0.0131 - output_Dc_mae: 0.0906 - output_b_loss: 0.0474 - output_b_mae: 0.2658 - output_sigma_loss: 0.0487 - output_sigma_mae: 0.1987 - val_loss: 0.1607 - val_output_Dc_loss: 0.0353 - val_output_Dc_mae: 0.1526 - val_output_b_loss: 0.0450 - val_output_b_mae: 0.2467 - val_output_sigma_loss: 0.0794 - val_output_sigma_mae: 0.2342 - learning_rate: 1.0000e-04
# Epoch 9/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1093 - output_Dc_loss: 0.0134 - output_Dc_mae: 0.0920 - output_b_loss: 0.0472 - output_b_mae: 0.2620 - output_sigma_loss: 0.0488 - output_sigma_mae: 0.1985
# Epoch 9: val_loss did not improve from 0.15525
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - loss: 0.1090 - output_Dc_loss: 0.0132 - output_Dc_mae: 0.0916 - output_b_loss: 0.0473 - output_b_mae: 0.2639 - output_sigma_loss: 0.0482 - output_sigma_mae: 0.1977 - val_loss: 0.3612 - val_output_Dc_loss: 0.2374 - val_output_Dc_mae: 0.3916 - val_output_b_loss: 0.0396 - val_output_b_mae: 0.2312 - val_output_sigma_loss: 0.0894 - val_output_sigma_mae: 0.2452 - learning_rate: 1.0000e-04
# Epoch 10/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1094 - output_Dc_loss: 0.0127 - output_Dc_mae: 0.0878 - output_b_loss: 0.0484 - output_b_mae: 0.2690 - output_sigma_loss: 0.0483 - output_sigma_mae: 0.1937
# Epoch 10: val_loss did not improve from 0.15525
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1087 - output_Dc_loss: 0.0126 - output_Dc_mae: 0.0875 - output_b_loss: 0.0474 - output_b_mae: 0.2651 - output_sigma_loss: 0.0486 - output_sigma_mae: 0.1959 - val_loss: 0.3430 - val_output_Dc_loss: 0.2461 - val_output_Dc_mae: 0.4143 - val_output_b_loss: 0.0348 - val_output_b_mae: 0.2177 - val_output_sigma_loss: 0.0575 - val_output_sigma_mae: 0.2219 - learning_rate: 1.0000e-04
# Epoch 11/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1089 - output_Dc_loss: 0.0134 - output_Dc_mae: 0.0919 - output_b_loss: 0.0474 - output_b_mae: 0.2631 - output_sigma_loss: 0.0480 - output_sigma_mae: 0.1972
# Epoch 11: val_loss improved from 0.15525 to 0.12280, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1083 - output_Dc_loss: 0.0134 - output_Dc_mae: 0.0910 - output_b_loss: 0.0468 - output_b_mae: 0.2627 - output_sigma_loss: 0.0478 - output_sigma_mae: 0.1954 - val_loss: 0.1228 - val_output_Dc_loss: 0.0400 - val_output_Dc_mae: 0.1516 - val_output_b_loss: 0.0331 - val_output_b_mae: 0.2127 - val_output_sigma_loss: 0.0517 - val_output_sigma_mae: 0.2098 - learning_rate: 1.0000e-04
# Epoch 12/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1063 - output_Dc_loss: 0.0127 - output_Dc_mae: 0.0887 - output_b_loss: 0.0465 - output_b_mae: 0.2612 - output_sigma_loss: 0.0471 - output_sigma_mae: 0.1931
# Epoch 12: val_loss did not improve from 0.12280
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1065 - output_Dc_loss: 0.0127 - output_Dc_mae: 0.0885 - output_b_loss: 0.0465 - output_b_mae: 0.2614 - output_sigma_loss: 0.0473 - output_sigma_mae: 0.1934 - val_loss: 0.1889 - val_output_Dc_loss: 0.0840 - val_output_Dc_mae: 0.2285 - val_output_b_loss: 0.0365 - val_output_b_mae: 0.2234 - val_output_sigma_loss: 0.0712 - val_output_sigma_mae: 0.2275 - learning_rate: 1.0000e-04
# Epoch 13/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1041 - output_Dc_loss: 0.0125 - output_Dc_mae: 0.0884 - output_b_loss: 0.0465 - output_b_mae: 0.2618 - output_sigma_loss: 0.0451 - output_sigma_mae: 0.1875
# Epoch 13: val_loss did not improve from 0.12280
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.1051 - output_Dc_loss: 0.0132 - output_Dc_mae: 0.0906 - output_b_loss: 0.0462 - output_b_mae: 0.2600 - output_sigma_loss: 0.0455 - output_sigma_mae: 0.1890 - val_loss: 0.3784 - val_output_Dc_loss: 0.1733 - val_output_Dc_mae: 0.3328 - val_output_b_loss: 0.0883 - val_output_b_mae: 0.3472 - val_output_sigma_loss: 0.1217 - val_output_sigma_mae: 0.2681 - learning_rate: 1.0000e-04
# Epoch 14/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1032 - output_Dc_loss: 0.0118 - output_Dc_mae: 0.0864 - output_b_loss: 0.0466 - output_b_mae: 0.2616 - output_sigma_loss: 0.0448 - output_sigma_mae: 0.1874
# Epoch 14: val_loss improved from 0.12280 to 0.11371, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1035 - output_Dc_loss: 0.0115 - output_Dc_mae: 0.0851 - output_b_loss: 0.0460 - output_b_mae: 0.2602 - output_sigma_loss: 0.0458 - output_sigma_mae: 0.1895 - val_loss: 0.1137 - val_output_Dc_loss: 0.0295 - val_output_Dc_mae: 0.1431 - val_output_b_loss: 0.0325 - val_output_b_mae: 0.2126 - val_output_sigma_loss: 0.0515 - val_output_sigma_mae: 0.2084 - learning_rate: 1.0000e-04
# Epoch 15/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1022 - output_Dc_loss: 0.0107 - output_Dc_mae: 0.0821 - output_b_loss: 0.0459 - output_b_mae: 0.2597 - output_sigma_loss: 0.0456 - output_sigma_mae: 0.1912
# Epoch 15: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.1018 - output_Dc_loss: 0.0116 - output_Dc_mae: 0.0853 - output_b_loss: 0.0449 - output_b_mae: 0.2565 - output_sigma_loss: 0.0453 - output_sigma_mae: 0.1888 - val_loss: 0.1294 - val_output_Dc_loss: 0.0154 - val_output_Dc_mae: 0.0996 - val_output_b_loss: 0.0405 - val_output_b_mae: 0.2353 - val_output_sigma_loss: 0.0754 - val_output_sigma_mae: 0.2091 - learning_rate: 1.0000e-04
# Epoch 16/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1044 - output_Dc_loss: 0.0120 - output_Dc_mae: 0.0868 - output_b_loss: 0.0472 - output_b_mae: 0.2631 - output_sigma_loss: 0.0452 - output_sigma_mae: 0.1835
# Epoch 16: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1023 - output_Dc_loss: 0.0117 - output_Dc_mae: 0.0858 - output_b_loss: 0.0457 - output_b_mae: 0.2583 - output_sigma_loss: 0.0450 - output_sigma_mae: 0.1847 - val_loss: 0.1633 - val_output_Dc_loss: 0.0758 - val_output_Dc_mae: 0.2262 - val_output_b_loss: 0.0340 - val_output_b_mae: 0.2140 - val_output_sigma_loss: 0.0524 - val_output_sigma_mae: 0.2150 - learning_rate: 1.0000e-04
# Epoch 17/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1008 - output_Dc_loss: 0.0113 - output_Dc_mae: 0.0841 - output_b_loss: 0.0460 - output_b_mae: 0.2584 - output_sigma_loss: 0.0436 - output_sigma_mae: 0.1851
# Epoch 17: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.1000 - output_Dc_loss: 0.0111 - output_Dc_mae: 0.0831 - output_b_loss: 0.0448 - output_b_mae: 0.2558 - output_sigma_loss: 0.0441 - output_sigma_mae: 0.1844 - val_loss: 0.3172 - val_output_Dc_loss: 0.2182 - val_output_Dc_mae: 0.3698 - val_output_b_loss: 0.0381 - val_output_b_mae: 0.2298 - val_output_sigma_loss: 0.0668 - val_output_sigma_mae: 0.2273 - learning_rate: 1.0000e-04
# Epoch 18/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1008 - output_Dc_loss: 0.0118 - output_Dc_mae: 0.0837 - output_b_loss: 0.0448 - output_b_mae: 0.2542 - output_sigma_loss: 0.0442 - output_sigma_mae: 0.1852
# Epoch 18: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.1011 - output_Dc_loss: 0.0119 - output_Dc_mae: 0.0840 - output_b_loss: 0.0453 - output_b_mae: 0.2571 - output_sigma_loss: 0.0440 - output_sigma_mae: 0.1838 - val_loss: 0.1854 - val_output_Dc_loss: 0.0780 - val_output_Dc_mae: 0.2328 - val_output_b_loss: 0.0392 - val_output_b_mae: 0.2296 - val_output_sigma_loss: 0.0667 - val_output_sigma_mae: 0.2215 - learning_rate: 1.0000e-04
# Epoch 19/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0974 - output_Dc_loss: 0.0112 - output_Dc_mae: 0.0825 - output_b_loss: 0.0433 - output_b_mae: 0.2505 - output_sigma_loss: 0.0429 - output_sigma_mae: 0.1831
# Epoch 19: val_loss did not improve from 0.11371
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21s 146ms/step - loss: 0.0979 - output_Dc_loss: 0.0117 - output_Dc_mae: 0.0843 - output_b_loss: 0.0440 - output_b_mae: 0.2525 - output_sigma_loss: 0.0426 - output_sigma_mae: 0.1798 - val_loss: 0.1754 - val_output_Dc_loss: 0.0860 - val_output_Dc_mae: 0.2310 - val_output_b_loss: 0.0337 - val_output_b_mae: 0.2143 - val_output_sigma_loss: 0.0544 - val_output_sigma_mae: 0.2131 - learning_rate: 1.0000e-04
# Epoch 20/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0960 - output_Dc_loss: 0.0101 - output_Dc_mae: 0.0789 - output_b_loss: 0.0434 - output_b_mae: 0.2506 - output_sigma_loss: 0.0425 - output_sigma_mae: 0.1803
# Epoch 20: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - loss: 0.0966 - output_Dc_loss: 0.0103 - output_Dc_mae: 0.0797 - output_b_loss: 0.0441 - output_b_mae: 0.2525 - output_sigma_loss: 0.0422 - output_sigma_mae: 0.1787 - val_loss: 0.1277 - val_output_Dc_loss: 0.0461 - val_output_Dc_mae: 0.1704 - val_output_b_loss: 0.0328 - val_output_b_mae: 0.2113 - val_output_sigma_loss: 0.0513 - val_output_sigma_mae: 0.1981 - learning_rate: 5.0000e-05
# Epoch 21/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0944 - output_Dc_loss: 0.0100 - output_Dc_mae: 0.0787 - output_b_loss: 0.0435 - output_b_mae: 0.2507 - output_sigma_loss: 0.0410 - output_sigma_mae: 0.1746
# Epoch 21: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0949 - output_Dc_loss: 0.0098 - output_Dc_mae: 0.0782 - output_b_loss: 0.0438 - output_b_mae: 0.2515 - output_sigma_loss: 0.0414 - output_sigma_mae: 0.1760 - val_loss: 0.1445 - val_output_Dc_loss: 0.0228 - val_output_Dc_mae: 0.1277 - val_output_b_loss: 0.0487 - val_output_b_mae: 0.2539 - val_output_sigma_loss: 0.0728 - val_output_sigma_mae: 0.2255 - learning_rate: 5.0000e-05
# Epoch 22/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0969 - output_Dc_loss: 0.0108 - output_Dc_mae: 0.0808 - output_b_loss: 0.0442 - output_b_mae: 0.2534 - output_sigma_loss: 0.0420 - output_sigma_mae: 0.1766
# Epoch 22: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0947 - output_Dc_loss: 0.0107 - output_Dc_mae: 0.0807 - output_b_loss: 0.0434 - output_b_mae: 0.2505 - output_sigma_loss: 0.0406 - output_sigma_mae: 0.1738 - val_loss: 0.1959 - val_output_Dc_loss: 0.0990 - val_output_Dc_mae: 0.2617 - val_output_b_loss: 0.0391 - val_output_b_mae: 0.2282 - val_output_sigma_loss: 0.0564 - val_output_sigma_mae: 0.2113 - learning_rate: 5.0000e-05
# Epoch 23/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0931 - output_Dc_loss: 0.0092 - output_Dc_mae: 0.0758 - output_b_loss: 0.0444 - output_b_mae: 0.2546 - output_sigma_loss: 0.0396 - output_sigma_mae: 0.1704
# Epoch 23: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0927 - output_Dc_loss: 0.0096 - output_Dc_mae: 0.0764 - output_b_loss: 0.0434 - output_b_mae: 0.2495 - output_sigma_loss: 0.0401 - output_sigma_mae: 0.1715 - val_loss: 0.1904 - val_output_Dc_loss: 0.1097 - val_output_Dc_mae: 0.2678 - val_output_b_loss: 0.0318 - val_output_b_mae: 0.2080 - val_output_sigma_loss: 0.0476 - val_output_sigma_mae: 0.1983 - learning_rate: 5.0000e-05
# Epoch 24/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0912 - output_Dc_loss: 0.0095 - output_Dc_mae: 0.0772 - output_b_loss: 0.0420 - output_b_mae: 0.2460 - output_sigma_loss: 0.0396 - output_sigma_mae: 0.1720
# Epoch 24: val_loss did not improve from 0.11371
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.0923 - output_Dc_loss: 0.0100 - output_Dc_mae: 0.0782 - output_b_loss: 0.0428 - output_b_mae: 0.2475 - output_sigma_loss: 0.0396 - output_sigma_mae: 0.1708 - val_loss: 0.4118 - val_output_Dc_loss: 0.2345 - val_output_Dc_mae: 0.3850 - val_output_b_loss: 0.0776 - val_output_b_mae: 0.3251 - val_output_sigma_loss: 0.1057 - val_output_sigma_mae: 0.2541 - learning_rate: 5.0000e-05
# Epoch 25/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0909 - output_Dc_loss: 0.0103 - output_Dc_mae: 0.0795 - output_b_loss: 0.0423 - output_b_mae: 0.2478 - output_sigma_loss: 0.0383 - output_sigma_mae: 0.1680
# Epoch 25: val_loss did not improve from 0.11371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0910 - output_Dc_loss: 0.0099 - output_Dc_mae: 0.0784 - output_b_loss: 0.0425 - output_b_mae: 0.2473 - output_sigma_loss: 0.0387 - output_sigma_mae: 0.1676 - val_loss: 0.1682 - val_output_Dc_loss: 0.0946 - val_output_Dc_mae: 0.2435 - val_output_b_loss: 0.0319 - val_output_b_mae: 0.2081 - val_output_sigma_loss: 0.0464 - val_output_sigma_mae: 0.1831 - learning_rate: 2.5000e-05
# Epoch 26/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0879 - output_Dc_loss: 0.0094 - output_Dc_mae: 0.0755 - output_b_loss: 0.0412 - output_b_mae: 0.2433 - output_sigma_loss: 0.0374 - output_sigma_mae: 0.1651
# Epoch 26: val_loss improved from 0.11371 to 0.08733, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.0886 - output_Dc_loss: 0.0092 - output_Dc_mae: 0.0749 - output_b_loss: 0.0419 - output_b_mae: 0.2452 - output_sigma_loss: 0.0377 - output_sigma_mae: 0.1662 - val_loss: 0.0873 - val_output_Dc_loss: 0.0105 - val_output_Dc_mae: 0.0827 - val_output_b_loss: 0.0331 - val_output_b_mae: 0.2094 - val_output_sigma_loss: 0.0448 - val_output_sigma_mae: 0.1738 - learning_rate: 2.5000e-05
# Epoch 27/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0901 - output_Dc_loss: 0.0091 - output_Dc_mae: 0.0745 - output_b_loss: 0.0422 - output_b_mae: 0.2446 - output_sigma_loss: 0.0388 - output_sigma_mae: 0.1673
# Epoch 27: val_loss improved from 0.08733 to 0.08340, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 27: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0894 - output_Dc_loss: 0.0092 - output_Dc_mae: 0.0752 - output_b_loss: 0.0419 - output_b_mae: 0.2446 - output_sigma_loss: 0.0384 - output_sigma_mae: 0.1663 - val_loss: 0.0834 - val_output_Dc_loss: 0.0100 - val_output_Dc_mae: 0.0796 - val_output_b_loss: 0.0314 - val_output_b_mae: 0.2053 - val_output_sigma_loss: 0.0429 - val_output_sigma_mae: 0.1789 - learning_rate: 2.5000e-05
# Epoch 28/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0885 - output_Dc_loss: 0.0085 - output_Dc_mae: 0.0728 - output_b_loss: 0.0414 - output_b_mae: 0.2436 - output_sigma_loss: 0.0386 - output_sigma_mae: 0.1671
# Epoch 28: val_loss improved from 0.08340 to 0.08040, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 28: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0891 - output_Dc_loss: 0.0092 - output_Dc_mae: 0.0749 - output_b_loss: 0.0420 - output_b_mae: 0.2454 - output_sigma_loss: 0.0380 - output_sigma_mae: 0.1660 - val_loss: 0.0804 - val_output_Dc_loss: 0.0080 - val_output_Dc_mae: 0.0676 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2061 - val_output_sigma_loss: 0.0425 - val_output_sigma_mae: 0.1804 - learning_rate: 2.5000e-05
# Epoch 29/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0871 - output_Dc_loss: 0.0091 - output_Dc_mae: 0.0743 - output_b_loss: 0.0402 - output_b_mae: 0.2391 - output_sigma_loss: 0.0378 - output_sigma_mae: 0.1652
# Epoch 29: val_loss did not improve from 0.08040
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0881 - output_Dc_loss: 0.0091 - output_Dc_mae: 0.0748 - output_b_loss: 0.0413 - output_b_mae: 0.2444 - output_sigma_loss: 0.0377 - output_sigma_mae: 0.1649 - val_loss: 0.1009 - val_output_Dc_loss: 0.0219 - val_output_Dc_mae: 0.1142 - val_output_b_loss: 0.0332 - val_output_b_mae: 0.2120 - val_output_sigma_loss: 0.0475 - val_output_sigma_mae: 0.1884 - learning_rate: 2.5000e-05
# Epoch 30/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0887 - output_Dc_loss: 0.0086 - output_Dc_mae: 0.0733 - output_b_loss: 0.0420 - output_b_mae: 0.2456 - output_sigma_loss: 0.0381 - output_sigma_mae: 0.1674
# Epoch 30: val_loss did not improve from 0.08040
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.0874 - output_Dc_loss: 0.0089 - output_Dc_mae: 0.0744 - output_b_loss: 0.0412 - output_b_mae: 0.2425 - output_sigma_loss: 0.0374 - output_sigma_mae: 0.1645 - val_loss: 0.1313 - val_output_Dc_loss: 0.0087 - val_output_Dc_mae: 0.0734 - val_output_b_loss: 0.0495 - val_output_b_mae: 0.2563 - val_output_sigma_loss: 0.0733 - val_output_sigma_mae: 0.2235 - learning_rate: 2.5000e-05
# Epoch 31/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0866 - output_Dc_loss: 0.0090 - output_Dc_mae: 0.0751 - output_b_loss: 0.0406 - output_b_mae: 0.2401 - output_sigma_loss: 0.0369 - output_sigma_mae: 0.1642
# Epoch 31: val_loss did not improve from 0.08040
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0869 - output_Dc_loss: 0.0090 - output_Dc_mae: 0.0747 - output_b_loss: 0.0417 - output_b_mae: 0.2442 - output_sigma_loss: 0.0363 - output_sigma_mae: 0.1624 - val_loss: 0.0988 - val_output_Dc_loss: 0.0263 - val_output_Dc_mae: 0.1283 - val_output_b_loss: 0.0316 - val_output_b_mae: 0.2084 - val_output_sigma_loss: 0.0427 - val_output_sigma_mae: 0.1767 - learning_rate: 2.5000e-05
# Epoch 32/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0845 - output_Dc_loss: 0.0089 - output_Dc_mae: 0.0750 - output_b_loss: 0.0396 - output_b_mae: 0.2371 - output_sigma_loss: 0.0360 - output_sigma_mae: 0.1591
# Epoch 32: val_loss did not improve from 0.08040
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.0863 - output_Dc_loss: 0.0088 - output_Dc_mae: 0.0746 - output_b_loss: 0.0408 - output_b_mae: 0.2421 - output_sigma_loss: 0.0366 - output_sigma_mae: 0.1611 - val_loss: 0.1627 - val_output_Dc_loss: 0.0329 - val_output_Dc_mae: 0.1387 - val_output_b_loss: 0.0533 - val_output_b_mae: 0.2661 - val_output_sigma_loss: 0.0783 - val_output_sigma_mae: 0.2251 - learning_rate: 2.5000e-05
# Epoch 33/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0854 - output_Dc_loss: 0.0090 - output_Dc_mae: 0.0756 - output_b_loss: 0.0407 - output_b_mae: 0.2408 - output_sigma_loss: 0.0357 - output_sigma_mae: 0.1580
# Epoch 33: val_loss did not improve from 0.08040
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - loss: 0.0863 - output_Dc_loss: 0.0091 - output_Dc_mae: 0.0757 - output_b_loss: 0.0409 - output_b_mae: 0.2411 - output_sigma_loss: 0.0364 - output_sigma_mae: 0.1611 - val_loss: 0.1308 - val_output_Dc_loss: 0.0493 - val_output_Dc_mae: 0.1861 - val_output_b_loss: 0.0335 - val_output_b_mae: 0.2118 - val_output_sigma_loss: 0.0477 - val_output_sigma_mae: 0.1918 - learning_rate: 2.5000e-05
# Epoch 34/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0842 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0715 - output_b_loss: 0.0401 - output_b_mae: 0.2382 - output_sigma_loss: 0.0359 - output_sigma_mae: 0.1603
# Epoch 34: val_loss did not improve from 0.08040
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0851 - output_Dc_loss: 0.0085 - output_Dc_mae: 0.0727 - output_b_loss: 0.0405 - output_b_mae: 0.2398 - output_sigma_loss: 0.0360 - output_sigma_mae: 0.1608 - val_loss: 0.1115 - val_output_Dc_loss: 0.0144 - val_output_Dc_mae: 0.0971 - val_output_b_loss: 0.0394 - val_output_b_mae: 0.2291 - val_output_sigma_loss: 0.0579 - val_output_sigma_mae: 0.2042 - learning_rate: 1.2500e-05
# Epoch 35/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0856 - output_Dc_loss: 0.0087 - output_Dc_mae: 0.0743 - output_b_loss: 0.0402 - output_b_mae: 0.2382 - output_sigma_loss: 0.0367 - output_sigma_mae: 0.1612
# Epoch 35: val_loss improved from 0.08040 to 0.07931, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.0857 - output_Dc_loss: 0.0087 - output_Dc_mae: 0.0740 - output_b_loss: 0.0409 - output_b_mae: 0.2407 - output_sigma_loss: 0.0361 - output_sigma_mae: 0.1607 - val_loss: 0.0793 - val_output_Dc_loss: 0.0094 - val_output_Dc_mae: 0.0708 - val_output_b_loss: 0.0315 - val_output_b_mae: 0.2065 - val_output_sigma_loss: 0.0399 - val_output_sigma_mae: 0.1675 - learning_rate: 1.2500e-05
# Epoch 36/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0860 - output_Dc_loss: 0.0083 - output_Dc_mae: 0.0726 - output_b_loss: 0.0408 - output_b_mae: 0.2417 - output_sigma_loss: 0.0370 - output_sigma_mae: 0.1617
# Epoch 36: val_loss did not improve from 0.07931
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0837 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0724 - output_b_loss: 0.0407 - output_b_mae: 0.2401 - output_sigma_loss: 0.0351 - output_sigma_mae: 0.1577 - val_loss: 0.1161 - val_output_Dc_loss: 0.0442 - val_output_Dc_mae: 0.1650 - val_output_b_loss: 0.0325 - val_output_b_mae: 0.2094 - val_output_sigma_loss: 0.0419 - val_output_sigma_mae: 0.1698 - learning_rate: 1.2500e-05
# Epoch 37/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0875 - output_Dc_loss: 0.0085 - output_Dc_mae: 0.0737 - output_b_loss: 0.0418 - output_b_mae: 0.2430 - output_sigma_loss: 0.0372 - output_sigma_mae: 0.1634
# Epoch 37: val_loss did not improve from 0.07931
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - loss: 0.0850 - output_Dc_loss: 0.0085 - output_Dc_mae: 0.0734 - output_b_loss: 0.0411 - output_b_mae: 0.2409 - output_sigma_loss: 0.0356 - output_sigma_mae: 0.1600 - val_loss: 0.0918 - val_output_Dc_loss: 0.0207 - val_output_Dc_mae: 0.1114 - val_output_b_loss: 0.0316 - val_output_b_mae: 0.2089 - val_output_sigma_loss: 0.0411 - val_output_sigma_mae: 0.1738 - learning_rate: 1.2500e-05
# Epoch 38/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0836 - output_Dc_loss: 0.0087 - output_Dc_mae: 0.0730 - output_b_loss: 0.0400 - output_b_mae: 0.2377 - output_sigma_loss: 0.0350 - output_sigma_mae: 0.1566
# Epoch 38: val_loss did not improve from 0.07931
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0846 - output_Dc_loss: 0.0093 - output_Dc_mae: 0.0740 - output_b_loss: 0.0412 - output_b_mae: 0.2412 - output_sigma_loss: 0.0346 - output_sigma_mae: 0.1561 - val_loss: 0.0893 - val_output_Dc_loss: 0.0072 - val_output_Dc_mae: 0.0631 - val_output_b_loss: 0.0345 - val_output_b_mae: 0.2149 - val_output_sigma_loss: 0.0485 - val_output_sigma_mae: 0.1909 - learning_rate: 1.2500e-05
# Epoch 39/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0828 - output_Dc_loss: 0.0087 - output_Dc_mae: 0.0732 - output_b_loss: 0.0398 - output_b_mae: 0.2369 - output_sigma_loss: 0.0343 - output_sigma_mae: 0.1574
# Epoch 39: val_loss did not improve from 0.07931
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0841 - output_Dc_loss: 0.0084 - output_Dc_mae: 0.0721 - output_b_loss: 0.0403 - output_b_mae: 0.2393 - output_sigma_loss: 0.0353 - output_sigma_mae: 0.1586 - val_loss: 0.0860 - val_output_Dc_loss: 0.0076 - val_output_Dc_mae: 0.0680 - val_output_b_loss: 0.0332 - val_output_b_mae: 0.2110 - val_output_sigma_loss: 0.0460 - val_output_sigma_mae: 0.1852 - learning_rate: 1.2500e-05
# Epoch 40/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0821 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0694 - output_b_loss: 0.0398 - output_b_mae: 0.2379 - output_sigma_loss: 0.0346 - output_sigma_mae: 0.1549
# Epoch 40: val_loss improved from 0.07931 to 0.07724, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 40: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - loss: 0.0831 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0709 - output_b_loss: 0.0401 - output_b_mae: 0.2384 - output_sigma_loss: 0.0350 - output_sigma_mae: 0.1567 - val_loss: 0.0772 - val_output_Dc_loss: 0.0073 - val_output_Dc_mae: 0.0665 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2056 - val_output_sigma_loss: 0.0399 - val_output_sigma_mae: 0.1720 - learning_rate: 1.2500e-05
# Epoch 41/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0841 - output_Dc_loss: 0.0084 - output_Dc_mae: 0.0727 - output_b_loss: 0.0416 - output_b_mae: 0.2440 - output_sigma_loss: 0.0341 - output_sigma_mae: 0.1563
# Epoch 41: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0830 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0706 - output_b_loss: 0.0403 - output_b_mae: 0.2393 - output_sigma_loss: 0.0345 - output_sigma_mae: 0.1562 - val_loss: 0.0810 - val_output_Dc_loss: 0.0090 - val_output_Dc_mae: 0.0699 - val_output_b_loss: 0.0320 - val_output_b_mae: 0.2085 - val_output_sigma_loss: 0.0412 - val_output_sigma_mae: 0.1734 - learning_rate: 1.2500e-05
# Epoch 42/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0825 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0702 - output_b_loss: 0.0394 - output_b_mae: 0.2374 - output_sigma_loss: 0.0350 - output_sigma_mae: 0.1568
# Epoch 42: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0830 - output_Dc_loss: 0.0083 - output_Dc_mae: 0.0712 - output_b_loss: 0.0399 - output_b_mae: 0.2388 - output_sigma_loss: 0.0348 - output_sigma_mae: 0.1564 - val_loss: 0.0835 - val_output_Dc_loss: 0.0090 - val_output_Dc_mae: 0.0681 - val_output_b_loss: 0.0325 - val_output_b_mae: 0.2089 - val_output_sigma_loss: 0.0433 - val_output_sigma_mae: 0.1803 - learning_rate: 1.2500e-05
# Epoch 43/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0819 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0698 - output_b_loss: 0.0391 - output_b_mae: 0.2352 - output_sigma_loss: 0.0351 - output_sigma_mae: 0.1580
# Epoch 43: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - loss: 0.0828 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0698 - output_b_loss: 0.0401 - output_b_mae: 0.2381 - output_sigma_loss: 0.0351 - output_sigma_mae: 0.1570 - val_loss: 0.0873 - val_output_Dc_loss: 0.0162 - val_output_Dc_mae: 0.1032 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2052 - val_output_sigma_loss: 0.0408 - val_output_sigma_mae: 0.1731 - learning_rate: 1.2500e-05
# Epoch 44/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0843 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0719 - output_b_loss: 0.0401 - output_b_mae: 0.2390 - output_sigma_loss: 0.0359 - output_sigma_mae: 0.1614
# Epoch 44: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0826 - output_Dc_loss: 0.0084 - output_Dc_mae: 0.0725 - output_b_loss: 0.0396 - output_b_mae: 0.2367 - output_sigma_loss: 0.0347 - output_sigma_mae: 0.1566 - val_loss: 0.2431 - val_output_Dc_loss: 0.1501 - val_output_Dc_mae: 0.3082 - val_output_b_loss: 0.0384 - val_output_b_mae: 0.2299 - val_output_sigma_loss: 0.0597 - val_output_sigma_mae: 0.2050 - learning_rate: 1.2500e-05
# Epoch 45/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0829 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0694 - output_b_loss: 0.0409 - output_b_mae: 0.2407 - output_sigma_loss: 0.0342 - output_sigma_mae: 0.1567
# Epoch 45: val_loss did not improve from 0.07724
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0821 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0703 - output_b_loss: 0.0399 - output_b_mae: 0.2379 - output_sigma_loss: 0.0341 - output_sigma_mae: 0.1552 - val_loss: 0.0859 - val_output_Dc_loss: 0.0085 - val_output_Dc_mae: 0.0683 - val_output_b_loss: 0.0330 - val_output_b_mae: 0.2115 - val_output_sigma_loss: 0.0455 - val_output_sigma_mae: 0.1837 - learning_rate: 1.2500e-05
# Epoch 46/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0846 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0696 - output_b_loss: 0.0404 - output_b_mae: 0.2394 - output_sigma_loss: 0.0364 - output_sigma_mae: 0.1604
# Epoch 46: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0819 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0700 - output_b_loss: 0.0396 - output_b_mae: 0.2366 - output_sigma_loss: 0.0343 - output_sigma_mae: 0.1558 - val_loss: 0.0788 - val_output_Dc_loss: 0.0070 - val_output_Dc_mae: 0.0617 - val_output_b_loss: 0.0317 - val_output_b_mae: 0.2075 - val_output_sigma_loss: 0.0412 - val_output_sigma_mae: 0.1742 - learning_rate: 6.2500e-06
# Epoch 47/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0808 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0690 - output_b_loss: 0.0391 - output_b_mae: 0.2364 - output_sigma_loss: 0.0340 - output_sigma_mae: 0.1545
# Epoch 47: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0815 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0702 - output_b_loss: 0.0394 - output_b_mae: 0.2371 - output_sigma_loss: 0.0342 - output_sigma_mae: 0.1544 - val_loss: 0.0874 - val_output_Dc_loss: 0.0179 - val_output_Dc_mae: 0.1016 - val_output_b_loss: 0.0317 - val_output_b_mae: 0.2087 - val_output_sigma_loss: 0.0395 - val_output_sigma_mae: 0.1700 - learning_rate: 6.2500e-06
# Epoch 48/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0818 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0697 - output_b_loss: 0.0391 - output_b_mae: 0.2334 - output_sigma_loss: 0.0348 - output_sigma_mae: 0.1568
# Epoch 48: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0816 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0708 - output_b_loss: 0.0396 - output_b_mae: 0.2360 - output_sigma_loss: 0.0340 - output_sigma_mae: 0.1550 - val_loss: 0.1067 - val_output_Dc_loss: 0.0369 - val_output_Dc_mae: 0.1518 - val_output_b_loss: 0.0322 - val_output_b_mae: 0.2091 - val_output_sigma_loss: 0.0401 - val_output_sigma_mae: 0.1664 - learning_rate: 6.2500e-06
# Epoch 49/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0826 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0696 - output_b_loss: 0.0393 - output_b_mae: 0.2378 - output_sigma_loss: 0.0355 - output_sigma_mae: 0.1563
# Epoch 49: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0810 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0686 - output_b_loss: 0.0393 - output_b_mae: 0.2366 - output_sigma_loss: 0.0341 - output_sigma_mae: 0.1541 - val_loss: 0.0957 - val_output_Dc_loss: 0.0240 - val_output_Dc_mae: 0.1204 - val_output_b_loss: 0.0330 - val_output_b_mae: 0.2098 - val_output_sigma_loss: 0.0407 - val_output_sigma_mae: 0.1643 - learning_rate: 6.2500e-06
# Epoch 50/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0833 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0707 - output_b_loss: 0.0408 - output_b_mae: 0.2420 - output_sigma_loss: 0.0344 - output_sigma_mae: 0.1560
# Epoch 50: val_loss did not improve from 0.07724
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - loss: 0.0817 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0711 - output_b_loss: 0.0398 - output_b_mae: 0.2377 - output_sigma_loss: 0.0337 - output_sigma_mae: 0.1536 - val_loss: 0.0995 - val_output_Dc_loss: 0.0291 - val_output_Dc_mae: 0.1344 - val_output_b_loss: 0.0318 - val_output_b_mae: 0.2091 - val_output_sigma_loss: 0.0406 - val_output_sigma_mae: 0.1714 - learning_rate: 6.2500e-06
# Epoch 51/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0808 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0704 - output_b_loss: 0.0395 - output_b_mae: 0.2363 - output_sigma_loss: 0.0334 - output_sigma_mae: 0.1544
# Epoch 51: val_loss did not improve from 0.07724
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0808 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0699 - output_b_loss: 0.0396 - output_b_mae: 0.2369 - output_sigma_loss: 0.0338 - output_sigma_mae: 0.1537 - val_loss: 0.0789 - val_output_Dc_loss: 0.0092 - val_output_Dc_mae: 0.0711 - val_output_b_loss: 0.0314 - val_output_b_mae: 0.2072 - val_output_sigma_loss: 0.0396 - val_output_sigma_mae: 0.1699 - learning_rate: 3.1250e-06
# Epoch 52/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0824 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0704 - output_b_loss: 0.0402 - output_b_mae: 0.2392 - output_sigma_loss: 0.0342 - output_sigma_mae: 0.1554
# Epoch 52: val_loss improved from 0.07724 to 0.07620, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 52: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0812 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0696 - output_b_loss: 0.0395 - output_b_mae: 0.2366 - output_sigma_loss: 0.0337 - output_sigma_mae: 0.1541 - val_loss: 0.0762 - val_output_Dc_loss: 0.0078 - val_output_Dc_mae: 0.0694 - val_output_b_loss: 0.0309 - val_output_b_mae: 0.2053 - val_output_sigma_loss: 0.0385 - val_output_sigma_mae: 0.1668 - learning_rate: 3.1250e-06
# Epoch 53/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0822 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0702 - output_b_loss: 0.0397 - output_b_mae: 0.2382 - output_sigma_loss: 0.0347 - output_sigma_mae: 0.1561
# Epoch 53: val_loss did not improve from 0.07620
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0814 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0716 - output_b_loss: 0.0395 - output_b_mae: 0.2363 - output_sigma_loss: 0.0337 - output_sigma_mae: 0.1534 - val_loss: 0.0806 - val_output_Dc_loss: 0.0081 - val_output_Dc_mae: 0.0707 - val_output_b_loss: 0.0318 - val_output_b_mae: 0.2069 - val_output_sigma_loss: 0.0416 - val_output_sigma_mae: 0.1751 - learning_rate: 3.1250e-06
# Epoch 54/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0807 - output_Dc_loss: 0.0075 - output_Dc_mae: 0.0676 - output_b_loss: 0.0409 - output_b_mae: 0.2411 - output_sigma_loss: 0.0323 - output_sigma_mae: 0.1507
# Epoch 54: val_loss improved from 0.07620 to 0.07448, saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
#
# Epoch 54: finished saving model to /content/drive/MyDrive/Tesi/checkpoints/model_best.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.0808 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0692 - output_b_loss: 0.0396 - output_b_mae: 0.2367 - output_sigma_loss: 0.0333 - output_sigma_mae: 0.1523 - val_loss: 0.0745 - val_output_Dc_loss: 0.0066 - val_output_Dc_mae: 0.0602 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2066 - val_output_sigma_loss: 0.0379 - val_output_sigma_mae: 0.1644 - learning_rate: 3.1250e-06
# Epoch 55/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0813 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0697 - output_b_loss: 0.0391 - output_b_mae: 0.2361 - output_sigma_loss: 0.0344 - output_sigma_mae: 0.1547
# Epoch 55: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0812 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0701 - output_b_loss: 0.0394 - output_b_mae: 0.2365 - output_sigma_loss: 0.0339 - output_sigma_mae: 0.1534 - val_loss: 0.0759 - val_output_Dc_loss: 0.0073 - val_output_Dc_mae: 0.0668 - val_output_b_loss: 0.0309 - val_output_b_mae: 0.2056 - val_output_sigma_loss: 0.0387 - val_output_sigma_mae: 0.1683 - learning_rate: 3.1250e-06
# Epoch 56/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0808 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0707 - output_b_loss: 0.0399 - output_b_mae: 0.2362 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1535
# Epoch 56: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - loss: 0.0813 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0710 - output_b_loss: 0.0396 - output_b_mae: 0.2361 - output_sigma_loss: 0.0337 - output_sigma_mae: 0.1536 - val_loss: 0.0767 - val_output_Dc_loss: 0.0065 - val_output_Dc_mae: 0.0604 - val_output_b_loss: 0.0313 - val_output_b_mae: 0.2062 - val_output_sigma_loss: 0.0400 - val_output_sigma_mae: 0.1711 - learning_rate: 3.1250e-06
# Epoch 57/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0810 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0709 - output_b_loss: 0.0402 - output_b_mae: 0.2376 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1535
# Epoch 57: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0808 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0700 - output_b_loss: 0.0397 - output_b_mae: 0.2368 - output_sigma_loss: 0.0333 - output_sigma_mae: 0.1536 - val_loss: 0.0783 - val_output_Dc_loss: 0.0100 - val_output_Dc_mae: 0.0746 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2071 - val_output_sigma_loss: 0.0385 - val_output_sigma_mae: 0.1673 - learning_rate: 3.1250e-06
# Epoch 58/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0809 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0694 - output_b_loss: 0.0387 - output_b_mae: 0.2326 - output_sigma_loss: 0.0343 - output_sigma_mae: 0.1552
# Epoch 58: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0808 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0697 - output_b_loss: 0.0393 - output_b_mae: 0.2348 - output_sigma_loss: 0.0335 - output_sigma_mae: 0.1535 - val_loss: 0.0775 - val_output_Dc_loss: 0.0072 - val_output_Dc_mae: 0.0625 - val_output_b_loss: 0.0314 - val_output_b_mae: 0.2069 - val_output_sigma_loss: 0.0400 - val_output_sigma_mae: 0.1710 - learning_rate: 3.1250e-06
# Epoch 59/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0787 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0709 - output_b_loss: 0.0377 - output_b_mae: 0.2291 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1515
# Epoch 59: val_loss did not improve from 0.07448
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0815 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0704 - output_b_loss: 0.0395 - output_b_mae: 0.2352 - output_sigma_loss: 0.0340 - output_sigma_mae: 0.1534 - val_loss: 0.0774 - val_output_Dc_loss: 0.0087 - val_output_Dc_mae: 0.0688 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2068 - val_output_sigma_loss: 0.0388 - val_output_sigma_mae: 0.1677 - learning_rate: 3.1250e-06
# Epoch 60/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0821 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0692 - output_b_loss: 0.0395 - output_b_mae: 0.2353 - output_sigma_loss: 0.0346 - output_sigma_mae: 0.1563
# Epoch 60: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0812 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0694 - output_b_loss: 0.0396 - output_b_mae: 0.2368 - output_sigma_loss: 0.0338 - output_sigma_mae: 0.1553 - val_loss: 0.0759 - val_output_Dc_loss: 0.0064 - val_output_Dc_mae: 0.0598 - val_output_b_loss: 0.0313 - val_output_b_mae: 0.2065 - val_output_sigma_loss: 0.0392 - val_output_sigma_mae: 0.1690 - learning_rate: 1.5625e-06
# Epoch 61/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0805 - output_Dc_loss: 0.0075 - output_Dc_mae: 0.0691 - output_b_loss: 0.0396 - output_b_mae: 0.2374 - output_sigma_loss: 0.0334 - output_sigma_mae: 0.1518
# Epoch 61: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0800 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0699 - output_b_loss: 0.0392 - output_b_mae: 0.2355 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1516 - val_loss: 0.0752 - val_output_Dc_loss: 0.0075 - val_output_Dc_mae: 0.0639 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2069 - val_output_sigma_loss: 0.0377 - val_output_sigma_mae: 0.1636 - learning_rate: 1.5625e-06
# Epoch 62/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0802 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0707 - output_b_loss: 0.0393 - output_b_mae: 0.2348 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1519
# Epoch 62: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - loss: 0.0810 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0697 - output_b_loss: 0.0393 - output_b_mae: 0.2366 - output_sigma_loss: 0.0337 - output_sigma_mae: 0.1535 - val_loss: 0.0763 - val_output_Dc_loss: 0.0086 - val_output_Dc_mae: 0.0688 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2072 - val_output_sigma_loss: 0.0378 - val_output_sigma_mae: 0.1638 - learning_rate: 1.5625e-06
# Epoch 63/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0809 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0699 - output_b_loss: 0.0390 - output_b_mae: 0.2354 - output_sigma_loss: 0.0338 - output_sigma_mae: 0.1543
# Epoch 63: val_loss did not improve from 0.07448
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.0805 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0693 - output_b_loss: 0.0395 - output_b_mae: 0.2360 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1522 - val_loss: 0.0775 - val_output_Dc_loss: 0.0071 - val_output_Dc_mae: 0.0620 - val_output_b_loss: 0.0315 - val_output_b_mae: 0.2070 - val_output_sigma_loss: 0.0399 - val_output_sigma_mae: 0.1704 - learning_rate: 1.5625e-06
# Epoch 64/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0787 - output_Dc_loss: 0.0075 - output_Dc_mae: 0.0684 - output_b_loss: 0.0382 - output_b_mae: 0.2334 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1522
# Epoch 64: val_loss did not improve from 0.07448
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step - loss: 0.0803 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0693 - output_b_loss: 0.0390 - output_b_mae: 0.2354 - output_sigma_loss: 0.0338 - output_sigma_mae: 0.1529 - val_loss: 0.0765 - val_output_Dc_loss: 0.0079 - val_output_Dc_mae: 0.0655 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2070 - val_output_sigma_loss: 0.0385 - val_output_sigma_mae: 0.1669 - learning_rate: 1.5625e-06
# Epoch 65/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0798 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0696 - output_b_loss: 0.0378 - output_b_mae: 0.2316 - output_sigma_loss: 0.0342 - output_sigma_mae: 0.1536
# Epoch 65: val_loss did not improve from 0.07448
# ...
# Epoch 99/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0796 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0707 - output_b_loss: 0.0389 - output_b_mae: 0.2351 - output_sigma_loss: 0.0327 - output_sigma_mae: 0.1517
# Epoch 99: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - loss: 0.0794 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0692 - output_b_loss: 0.0384 - output_b_mae: 0.2331 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1518 - val_loss: 0.0742 - val_output_Dc_loss: 0.0064 - val_output_Dc_mae: 0.0594 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2061 - val_output_sigma_loss: 0.0379 - val_output_sigma_mae: 0.1652 - learning_rate: 1.0000e-06
# Epoch 100/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0822 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0702 - output_b_loss: 0.0400 - output_b_mae: 0.2369 - output_sigma_loss: 0.0341 - output_sigma_mae: 0.1548
# Epoch 100: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - loss: 0.0803 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0703 - output_b_loss: 0.0388 - output_b_mae: 0.2334 - output_sigma_loss: 0.0335 - output_sigma_mae: 0.1529 - val_loss: 0.0743 - val_output_Dc_loss: 0.0062 - val_output_Dc_mae: 0.0591 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2059 - val_output_sigma_loss: 0.0381 - val_output_sigma_mae: 0.1659 - learning_rate: 1.0000e-06
# Epoch 101/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0801 - output_Dc_loss: 0.0074 - output_Dc_mae: 0.0681 - output_b_loss: 0.0398 - output_b_mae: 0.2371 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1510
# Epoch 101: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - loss: 0.0792 - output_Dc_loss: 0.0074 - output_Dc_mae: 0.0673 - output_b_loss: 0.0387 - output_b_mae: 0.2332 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1523 - val_loss: 0.0755 - val_output_Dc_loss: 0.0080 - val_output_Dc_mae: 0.0663 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2068 - val_output_sigma_loss: 0.0375 - val_output_sigma_mae: 0.1632 - learning_rate: 1.0000e-06
# Epoch 102/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0797 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0707 - output_b_loss: 0.0382 - output_b_mae: 0.2341 - output_sigma_loss: 0.0334 - output_sigma_mae: 0.1535
# Epoch 102: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0800 - output_Dc_loss: 0.0082 - output_Dc_mae: 0.0703 - output_b_loss: 0.0389 - output_b_mae: 0.2348 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1519 - val_loss: 0.0743 - val_output_Dc_loss: 0.0063 - val_output_Dc_mae: 0.0598 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2056 - val_output_sigma_loss: 0.0380 - val_output_sigma_mae: 0.1655 - learning_rate: 1.0000e-06
# Epoch 103/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0779 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0683 - output_b_loss: 0.0393 - output_b_mae: 0.2345 - output_sigma_loss: 0.0310 - output_sigma_mae: 0.1467
# Epoch 103: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 146ms/step - loss: 0.0800 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0681 - output_b_loss: 0.0395 - output_b_mae: 0.2360 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1512 - val_loss: 0.0797 - val_output_Dc_loss: 0.0123 - val_output_Dc_mae: 0.0843 - val_output_b_loss: 0.0315 - val_output_b_mae: 0.2078 - val_output_sigma_loss: 0.0374 - val_output_sigma_mae: 0.1615 - learning_rate: 1.0000e-06
# Epoch 104/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0778 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0696 - output_b_loss: 0.0382 - output_b_mae: 0.2333 - output_sigma_loss: 0.0318 - output_sigma_mae: 0.1491
# Epoch 104: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0800 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0701 - output_b_loss: 0.0389 - output_b_mae: 0.2350 - output_sigma_loss: 0.0330 - output_sigma_mae: 0.1511 - val_loss: 0.0745 - val_output_Dc_loss: 0.0064 - val_output_Dc_mae: 0.0592 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2059 - val_output_sigma_loss: 0.0382 - val_output_sigma_mae: 0.1661 - learning_rate: 1.0000e-06
# Epoch 105/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0784 - output_Dc_loss: 0.0085 - output_Dc_mae: 0.0725 - output_b_loss: 0.0385 - output_b_mae: 0.2340 - output_sigma_loss: 0.0314 - output_sigma_mae: 0.1485
# Epoch 105: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0799 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0694 - output_b_loss: 0.0389 - output_b_mae: 0.2342 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1516 - val_loss: 0.0744 - val_output_Dc_loss: 0.0063 - val_output_Dc_mae: 0.0594 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2056 - val_output_sigma_loss: 0.0382 - val_output_sigma_mae: 0.1663 - learning_rate: 1.0000e-06
# Epoch 106/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0777 - output_Dc_loss: 0.0072 - output_Dc_mae: 0.0672 - output_b_loss: 0.0376 - output_b_mae: 0.2314 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1526
# Epoch 106: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0797 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0688 - output_b_loss: 0.0390 - output_b_mae: 0.2346 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1518 - val_loss: 0.0741 - val_output_Dc_loss: 0.0064 - val_output_Dc_mae: 0.0594 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2060 - val_output_sigma_loss: 0.0377 - val_output_sigma_mae: 0.1644 - learning_rate: 1.0000e-06
# Epoch 107/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0805 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0695 - output_b_loss: 0.0400 - output_b_mae: 0.2382 - output_sigma_loss: 0.0326 - output_sigma_mae: 0.1514
# Epoch 107: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0799 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0687 - output_b_loss: 0.0392 - output_b_mae: 0.2354 - output_sigma_loss: 0.0330 - output_sigma_mae: 0.1509 - val_loss: 0.0747 - val_output_Dc_loss: 0.0063 - val_output_Dc_mae: 0.0591 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2057 - val_output_sigma_loss: 0.0384 - val_output_sigma_mae: 0.1667 - learning_rate: 1.0000e-06
# Epoch 108/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0808 - output_Dc_loss: 0.0088 - output_Dc_mae: 0.0736 - output_b_loss: 0.0379 - output_b_mae: 0.2317 - output_sigma_loss: 0.0342 - output_sigma_mae: 0.1530
# Epoch 108: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0800 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0696 - output_b_loss: 0.0390 - output_b_mae: 0.2356 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1518 - val_loss: 0.0750 - val_output_Dc_loss: 0.0078 - val_output_Dc_mae: 0.0649 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2070 - val_output_sigma_loss: 0.0372 - val_output_sigma_mae: 0.1618 - learning_rate: 1.0000e-06
# Epoch 109/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0797 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0682 - output_b_loss: 0.0393 - output_b_mae: 0.2351 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1513
# Epoch 109: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0793 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0687 - output_b_loss: 0.0390 - output_b_mae: 0.2347 - output_sigma_loss: 0.0325 - output_sigma_mae: 0.1503 - val_loss: 0.0762 - val_output_Dc_loss: 0.0085 - val_output_Dc_mae: 0.0685 - val_output_b_loss: 0.0312 - val_output_b_mae: 0.2070 - val_output_sigma_loss: 0.0377 - val_output_sigma_mae: 0.1637 - learning_rate: 1.0000e-06
# Epoch 110/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0799 - output_Dc_loss: 0.0075 - output_Dc_mae: 0.0677 - output_b_loss: 0.0396 - output_b_mae: 0.2362 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1519
# Epoch 110: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0791 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0683 - output_b_loss: 0.0390 - output_b_mae: 0.2343 - output_sigma_loss: 0.0326 - output_sigma_mae: 0.1502 - val_loss: 0.0740 - val_output_Dc_loss: 0.0067 - val_output_Dc_mae: 0.0603 - val_output_b_loss: 0.0310 - val_output_b_mae: 0.2062 - val_output_sigma_loss: 0.0375 - val_output_sigma_mae: 0.1638 - learning_rate: 1.0000e-06
# Epoch 111/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0791 - output_Dc_loss: 0.0075 - output_Dc_mae: 0.0679 - output_b_loss: 0.0384 - output_b_mae: 0.2328 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1516
# Epoch 111: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0795 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0690 - output_b_loss: 0.0387 - output_b_mae: 0.2335 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1519 - val_loss: 0.0743 - val_output_Dc_loss: 0.0069 - val_output_Dc_mae: 0.0611 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2064 - val_output_sigma_loss: 0.0375 - val_output_sigma_mae: 0.1639 - learning_rate: 1.0000e-06
# Epoch 112/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0781 - output_Dc_loss: 0.0071 - output_Dc_mae: 0.0661 - output_b_loss: 0.0374 - output_b_mae: 0.2297 - output_sigma_loss: 0.0335 - output_sigma_mae: 0.1535
# Epoch 112: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - loss: 0.0799 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0680 - output_b_loss: 0.0391 - output_b_mae: 0.2349 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1515 - val_loss: 0.0748 - val_output_Dc_loss: 0.0072 - val_output_Dc_mae: 0.0625 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2065 - val_output_sigma_loss: 0.0376 - val_output_sigma_mae: 0.1642 - learning_rate: 1.0000e-06
# Epoch 113/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0775 - output_Dc_loss: 0.0071 - output_Dc_mae: 0.0661 - output_b_loss: 0.0387 - output_b_mae: 0.2343 - output_sigma_loss: 0.0318 - output_sigma_mae: 0.1490
# Epoch 113: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - loss: 0.0791 - output_Dc_loss: 0.0074 - output_Dc_mae: 0.0678 - output_b_loss: 0.0390 - output_b_mae: 0.2344 - output_sigma_loss: 0.0327 - output_sigma_mae: 0.1511 - val_loss: 0.0752 - val_output_Dc_loss: 0.0075 - val_output_Dc_mae: 0.0678 - val_output_b_loss: 0.0308 - val_output_b_mae: 0.2050 - val_output_sigma_loss: 0.0378 - val_output_sigma_mae: 0.1654 - learning_rate: 1.0000e-06
# Epoch 114/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0811 - output_Dc_loss: 0.0083 - output_Dc_mae: 0.0714 - output_b_loss: 0.0397 - output_b_mae: 0.2381 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1519
# Epoch 114: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - loss: 0.0798 - output_Dc_loss: 0.0081 - output_Dc_mae: 0.0701 - output_b_loss: 0.0385 - output_b_mae: 0.2343 - output_sigma_loss: 0.0331 - output_sigma_mae: 0.1513 - val_loss: 0.0751 - val_output_Dc_loss: 0.0070 - val_output_Dc_mae: 0.0617 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2064 - val_output_sigma_loss: 0.0381 - val_output_sigma_mae: 0.1658 - learning_rate: 1.0000e-06
# Epoch 115/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0795 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0700 - output_b_loss: 0.0391 - output_b_mae: 0.2353 - output_sigma_loss: 0.0324 - output_sigma_mae: 0.1494
# Epoch 115: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.0794 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0695 - output_b_loss: 0.0390 - output_b_mae: 0.2348 - output_sigma_loss: 0.0327 - output_sigma_mae: 0.1504 - val_loss: 0.0749 - val_output_Dc_loss: 0.0063 - val_output_Dc_mae: 0.0593 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2059 - val_output_sigma_loss: 0.0386 - val_output_sigma_mae: 0.1673 - learning_rate: 1.0000e-06
# Epoch 116/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0793 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0698 - output_b_loss: 0.0384 - output_b_mae: 0.2329 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1512
# Epoch 116: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - loss: 0.0795 - output_Dc_loss: 0.0077 - output_Dc_mae: 0.0687 - output_b_loss: 0.0389 - output_b_mae: 0.2338 - output_sigma_loss: 0.0328 - output_sigma_mae: 0.1516 - val_loss: 0.0771 - val_output_Dc_loss: 0.0090 - val_output_Dc_mae: 0.0764 - val_output_b_loss: 0.0308 - val_output_b_mae: 0.2047 - val_output_sigma_loss: 0.0382 - val_output_sigma_mae: 0.1665 - learning_rate: 1.0000e-06
# Epoch 117/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0791 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0700 - output_b_loss: 0.0397 - output_b_mae: 0.2370 - output_sigma_loss: 0.0315 - output_sigma_mae: 0.1475
# Epoch 117: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0788 - output_Dc_loss: 0.0074 - output_Dc_mae: 0.0674 - output_b_loss: 0.0394 - output_b_mae: 0.2365 - output_sigma_loss: 0.0322 - output_sigma_mae: 0.1486 - val_loss: 0.0782 - val_output_Dc_loss: 0.0107 - val_output_Dc_mae: 0.0777 - val_output_b_loss: 0.0313 - val_output_b_mae: 0.2074 - val_output_sigma_loss: 0.0376 - val_output_sigma_mae: 0.1633 - learning_rate: 1.0000e-06
# Epoch 118/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0777 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0670 - output_b_loss: 0.0379 - output_b_mae: 0.2300 - output_sigma_loss: 0.0322 - output_sigma_mae: 0.1516
# Epoch 118: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - loss: 0.0797 - output_Dc_loss: 0.0076 - output_Dc_mae: 0.0679 - output_b_loss: 0.0391 - output_b_mae: 0.2339 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1520 - val_loss: 0.0747 - val_output_Dc_loss: 0.0074 - val_output_Dc_mae: 0.0634 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2065 - val_output_sigma_loss: 0.0374 - val_output_sigma_mae: 0.1631 - learning_rate: 1.0000e-06
# Epoch 119/500
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0804 - output_Dc_loss: 0.0083 - output_Dc_mae: 0.0700 - output_b_loss: 0.0391 - output_b_mae: 0.2343 - output_sigma_loss: 0.0330 - output_sigma_mae: 0.1511
# Epoch 119: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - loss: 0.0792 - output_Dc_loss: 0.0079 - output_Dc_mae: 0.0686 - output_b_loss: 0.0393 - output_b_mae: 0.2347 - output_sigma_loss: 0.0323 - output_sigma_mae: 0.1490 - val_loss: 0.0744 - val_output_Dc_loss: 0.0064 - val_output_Dc_mae: 0.0594 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2060 - val_output_sigma_loss: 0.0380 - val_output_sigma_mae: 0.1653 - learning_rate: 1.0000e-06
# Epoch 120/500
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0789 - output_Dc_loss: 0.0080 - output_Dc_mae: 0.0708 - output_b_loss: 0.0377 - output_b_mae: 0.2310 - output_sigma_loss: 0.0332 - output_sigma_mae: 0.1510
# Epoch 120: val_loss did not improve from 0.07391
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - loss: 0.0790 - output_Dc_loss: 0.0078 - output_Dc_mae: 0.0697 - output_b_loss: 0.0383 - output_b_mae: 0.2331 - output_sigma_loss: 0.0329 - output_sigma_mae: 0.1508 - val_loss: 0.0747 - val_output_Dc_loss: 0.0063 - val_output_Dc_mae: 0.0602 - val_output_b_loss: 0.0311 - val_output_b_mae: 0.2056 - val_output_sigma_loss: 0.0383 - val_output_sigma_mae: 0.1665 - learning_rate: 1.0000e-06
# Epoch 120: early stopping
# Restoring model weights from the end of the best epoch: 90.

# %%
print(f"Epoche completate: {len(history.history['loss'])}")
print(f"Loss totale finale training:   {history.history['loss'][-1]:.6f}")
print(f"Loss totale finale validation: {history.history['val_loss'][-1]:.6f}")
print()

for nome_chiave, nome_display in [("output_b", "b"), ("output_Dc", "Dc"), ("output_sigma", "sigma_n")]:
    mae_train = history.history[f"{nome_chiave}_mae"][-1]
    mae_val   = history.history[f"val_{nome_chiave}_mae"][-1]
    print(f"MAE finale {nome_display:<10} — training: {mae_train:.6f}  |  validation: {mae_val:.6f}")

print(f"\nMiglior val_loss: {min(history.history['val_loss']):.6f}")
print(f"Raggiunta all'epoca: {history.history['val_loss'].index(min(history.history['val_loss'])) + 1}")
# Out:
# Epoche completate: 120
# Loss totale finale training:   0.078987
# Loss totale finale validation: 0.074688
#
# MAE finale b          — training: 0.233105  |  validation: 0.205556
# MAE finale Dc         — training: 0.069713  |  validation: 0.060166
# MAE finale sigma_n    — training: 0.150759  |  validation: 0.166509
#
# Miglior val_loss: 0.073914
# Raggiunta all'epoca: 90

# %% [markdown]
# ---
# #Grafici training
# ---

# %%
fig, axes = plt.subplots(2, 2, figsize=(13, 9))

axes[0,0].plot(history.history["loss"],     label="Training")
axes[0,0].plot(history.history["val_loss"], label="Validation")
axes[0,0].set_title("Loss totale (somma pesata)")
axes[0,0].set_xlabel("Epoca"); axes[0,0].set_ylabel("MSE")
axes[0,0].legend(); axes[0,0].grid(True, linestyle=":", alpha=0.6)

parametri_loss = [("output_b_loss", "b"), ("output_Dc_loss", "Dc"), ("output_sigma_loss", "sigma_n")]
posizioni = [(0,1), (1,0), (1,1)]

for (chiave, nome), (r, c) in zip(parametri_loss, posizioni):
    axes[r,c].plot(history.history[chiave],          label="Training")
    axes[r,c].plot(history.history[f"val_{chiave}"], label="Validation")
    axes[r,c].set_title(f"Loss — {nome}")
    axes[r,c].set_xlabel("Epoca"); axes[r,c].set_ylabel("MSE")
    axes[r,c].legend(); axes[r,c].grid(True, linestyle=":", alpha=0.6)

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
parametri_mae = [("output_b_mae", "b"), ("output_Dc_mae", "Dc"), ("output_sigma_mae", "sigma_n")]

for i, (chiave, nome) in enumerate(parametri_mae):
    axes[i].plot(history.history[chiave],          label="Training")
    axes[i].plot(history.history[f"val_{chiave}"], label="Validation")
    axes[i].set_title(f"MAE — {nome}")
    axes[i].set_xlabel("Epoca")
    axes[i].legend(); axes[i].grid(True, linestyle=":", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #Validation
# ---

# %%
Y_min = np.load(os.path.join(cartella_grafici, "norm_Y_min.npy"))
Y_max = np.load(os.path.join(cartella_grafici, "norm_Y_max.npy"))
nomi  = ["b", "Dc [m]", "sigma_n [Pa]"]

pred_list = model.predict(
    {
        "slip_profile_vel":  X_vel_test,
        "slip_profile_time": X_time_test,
        "fase_ciclo":        X_fase_test,
        "texture_features":  X_texture_test,
    }
)
Y_pred_norm = np.concatenate(pred_list, axis=1)
Y_pred = Y_pred_norm * (Y_max - Y_min) + Y_min
Y_real = Y_test      * (Y_max - Y_min) + Y_min

print(f"{'Parametro':<15} {'MAE':>12} {'RMSE':>12}")
print("-" * 42)
for i, nome in enumerate(nomi):
    mae  = np.mean(np.abs(Y_pred[:, i] - Y_real[:, i]))
    rmse = np.sqrt(np.mean((Y_pred[:, i] - Y_real[:, i])**2))
    print(f"{nome:<15} {mae:>12.4e} {rmse:>12.4e}")

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, nome in enumerate(nomi):
    axes[i].scatter(Y_real[:, i], Y_pred[:, i], alpha=0.5, s=20, color="steelblue")
    lim = [min(Y_real[:, i].min(), Y_pred[:, i].min()),
           max(Y_real[:, i].max(), Y_pred[:, i].max())]
    axes[i].plot(lim, lim, "r--", lw=1.5, label="Predizione perfetta")
    axes[i].set_xlabel(f"{nome} reale"); axes[i].set_ylabel(f"{nome} predetto")
    axes[i].set_title(nome); axes[i].legend()
    axes[i].grid(True, linestyle=":", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step
# Parametro                MAE         RMSE
# ------------------------------------------
# b                 6.1815e-04   7.4402e-04
# Dc [m]            2.3778e-07   3.1382e-07
# sigma_n [Pa]      6.5653e+06   7.6946e+06

# %% [markdown]
# ---
# #Predici evento
# ---

# %%
def predici_evento(path_vel, path_time):
  norm_vel  = np.load(os.path.join(cartella_grafici, "norm_vel.npy"))
  norm_time = np.load(os.path.join(cartella_grafici, "norm_time.npy"))
  Y_min     = np.load(os.path.join(cartella_grafici, "norm_Y_min.npy"))
  Y_max     = np.load(os.path.join(cartella_grafici, "norm_Y_max.npy"))
  tex_mean  = np.load(os.path.join(cartella_grafici, "tex_mean.npy"))
  tex_std   = np.load(os.path.join(cartella_grafici, "tex_std.npy"))

  dati = np.load(path_meta, allow_pickle=True)
  meta = json.loads(str(dati['metadati']))
  tmin_s = meta['tmin_s']
  TMAX   = meta['TMAX']

  img_vel_raw  = np.array(Image.open(path_vel).convert("L").resize(IMG_SIZE), dtype=np.float32)
  img_vel  = (img_vel_raw - norm_vel[0]) / (norm_vel[1] - norm_vel[0])

  img_time_raw = np.array(Image.open(path_time).convert("L").resize(IMG_SIZE), dtype=np.float32)
  img_time = (img_time_raw - norm_time[0]) / (norm_time[1] - norm_time[0])

  fase = tmin_s / TMAX if TMAX > 0 else 0.0
  texture = calcola_feature_texture(img_vel, img_time)
  texture_norm = (texture - tex_mean) / tex_std

  pred_list = model.predict(
      {
          "slip_profile_vel":  img_vel[np.newaxis, ..., np.newaxis],
          "slip_profile_time": img_time[np.newaxis, ..., np.newaxis],
          "fase_ciclo":        np.array([[fase]], dtype=np.float32),
          "texture_features":  texture_norm[np.newaxis, :],
      },
      verbose=0
  )
  pred_norm = np.array([p[0, 0] for p in pred_list])
  pred = pred_norm * (Y_max - Y_min) + Y_min

  print("─" * 40)
  print(f"{'Parametro':<15} {'Predetto':>14}")
  print("─" * 40)
  print(f"{'b':<15} {pred[0]:>14.4e}")
  print(f"{'Dc [m]':<15} {pred[1]:>14.4e}")
  print(f"{'sigma_n [Pa]':<15} {pred[2]:>14.4e}")
  print("─" * 40)

  fig, axes = plt.subplots(1, 2, figsize=(10, 4))
  axes[0].imshow(Image.open(path_vel))
  axes[0].set_title("Slip profile (velocita')")
  axes[0].axis("off")
  axes[1].imshow(Image.open(path_time))
  axes[1].set_title("Slip profile (tempo)")
  axes[1].axis("off")
  plt.suptitle(
      f"b = {pred[0]:.4e}   |   Dc = {pred[1]:.4e} m   |   σn = {pred[2]:.4e} Pa",
      fontsize=11
  )
  plt.tight_layout()
  plt.show()

  return pred

# %% [markdown]
# ---
# #Utilizzo
# ---

# %%
pred = predici_evento(
    path_vel  = "/content/drive/MyDrive/Tesi/Grafici/Simulazione_46_20260706/Evento_005/slip_profile.png",
    path_time = "/content/drive/MyDrive/Tesi/Grafici/Simulazione_46_20260706/Evento_005/slip_profile_time.png")
# Out:
# ────────────────────────────────────────
# Parametro             Predetto
# ────────────────────────────────────────
# b                   1.1572e-02
# Dc [m]              3.8179e-06
# sigma_n [Pa]        8.9697e+07
# ────────────────────────────────────────

# %%
path_meta_check = "/content/drive/MyDrive/Tesi/Grafici/Simulazione_46_20260706/Evento_005/dati.npz"
dati_check = np.load(path_meta_check, allow_pickle=True)
meta_check = json.loads(str(dati_check['metadati']))

print(f"b:            {meta_check['b']}")
print(f"Dc [m]:       {meta_check['Dc_m']}")
print(f"sigma_n [Pa]: {meta_check['sigma_n_Pa']}")
print(f"simulazione_n: {meta_check['simulazione_n']}")
# Out:
# b:            0.01275
# Dc [m]:       3.75e-06
# sigma_n [Pa]: 80000000.0
# simulazione_n: 46
